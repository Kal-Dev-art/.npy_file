# %%
import numpy as np

# %%
components_path = "C:\\Users\\khali\\Downloads\\OneDrive_1_3-11-2025\\components.npy"

# %%
data = np.load("components.npy")

# %%
print(data)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 2.71595373e-38
#   1.28350690e-22 3.16747120e-18 4.31684626e-16 8.64270015e-15
#   6.89958890e-14 3.29886781e-13 1.15017352e-12 3.25406881e-12
#   7.95653327e-12 1.74920163e-11 3.54902848e-11 6.76567989e-11
#   1.22733056e-10 2.13835464e-10 3.60300601e-10 5.90201211e-10
#   9.43742319e-10 1.47780169e-09 2.27194519e-09 3.43632731e-09
#   5.12198281e-09 7.53413258e-09 1.09492748e-08 1.57370352e-08
#   2.23880565e-08 3.15497233e-08 4.40724671e-08 6.10711923e-08
#   8.40098191e-08 1.14823423e-07 1.56104284e-07 2.11398870e-07
#   2.85697384e-07 3.86252239e-07 5.23943228e-07 7.15519438e-07
#   9.87188492e-07 1.38017631e-06 1.95900716e-06 2.82328630e-06
#   4.12360665e-06 6.08172304e-06 9.01422308e-06 1.33575039e-05
#   1.96899882e-05 2.87454182e-05 4.14092236e-05 5.86890657e-05
#   8.16515197e-05 1.11320185e-04 1.48536623e-04 1.93794042e-04
# ...

# %%
mixture_spectrum_path = "C:\\Users\\khali\\Downloads\\OneDrive_1_3-11-2025\\mixture_spectrum.npy"

# %%
data2 = np.load("mixture_spectrum.npy")

# %%
print(data2)
# Out:
# [0.0168     0.016832   0.016864   0.016896   0.016928   0.01696
#  0.016992   0.017024   0.017056   0.017088   0.01712004 0.01715257
#  0.01718742 0.01722834 0.01728061 0.0173502  0.01744319 0.01756554
#  0.01772312 0.01792193 0.01816829 0.01846908 0.01883173 0.01926413
#  0.01977425 0.02036959 0.02105641 0.02183883 0.0227178  0.02369025
#  0.02474833 0.02587903 0.02706424 0.02828135 0.02950433 0.03070538
#  0.03185684 0.03293328 0.0339136  0.03478272 0.03553285 0.0361641
#  0.03668431 0.0371083  0.03745638 0.03775252 0.0380223  0.03829087
#  0.03858118 0.03891262 0.03930016 0.03975415 0.04028052 0.04088142
#  0.04155608 0.04230163 0.04311371 0.04398668 0.04491341 0.04588451
#  0.04688737 0.04790502 0.04891542 0.04989126 0.05080077 0.05160945
#  0.05228287 0.05278994 0.05310645 0.05321805 0.05312229 0.05282923
#  0.05236045 0.05174678 0.05102484 0.05023327 0.04940906 0.04858466
#  0.04778614 0.0470327  0.04633728 0.04570823 0.04515146 0.04467276
# ...

# %%
concentrations, _, _, _ = np.linalg.lstsq(data.T,data2.T, rcond=None)

# %%
print("Calculated concentrations (g/L):")
print(f"Component A: {concentrations[0]:.2f} g/L")
print(f"Component B: {concentrations[1]:.2f} g/L")
print(f"Component C: {concentrations[2]:.2f} g/L")
# Out:
# Calculated concentrations (g/L):
# Component A: 23.86 g/L
# Component B: 48.38 g/L
# Component C: 22.87 g/L
